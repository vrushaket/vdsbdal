# %% [markdown]
# Name : Rutuja Banginwar
#
# Roll No.: 31303
#
# Class: TE03
#
# Batch: K3
#
# Subject: DSBDAL
#
# Assignment No.: 5
#
# ## Data Analytics II<a href="#Data-Analytics-II" class="anchor-link">¶</a>
#
# 1.  Implement logistic regression using Python/R to perform
#     classification on Social_Network_Ads.csv dataset.
#
# 2.  Compute Confusion matrix to find TP, FP, TN, FN, Accuracy, Error
#     rate, Precision, Recall on the given dataset.
#
# ### Import Required Libraries<a href="#Import-Required-Libraries" class="anchor-link">¶</a>
#
# In \[1\]:
#
#     import pandas as pd
#     import numpy as np
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     %matplotlib inline
#
# ### Read the CSV File<a href="#Read-the-CSV-File" class="anchor-link">¶</a>
#
# In \[2\]:
#
#     df = pd.read_csv('Social_Network_Ads.csv')
#
# In \[3\]:
#
#     df.head()
#
# Out\[3\]:
#
# |     | User ID  | Gender | Age | EstimatedSalary | Purchased |
# |-----|----------|--------|-----|-----------------|-----------|
# | 0   | 15624510 | Male   | 19  | 19000           | 0         |
# | 1   | 15810944 | Male   | 35  | 20000           | 0         |
# | 2   | 15668575 | Female | 26  | 43000           | 0         |
# | 3   | 15603246 | Female | 27  | 57000           | 0         |
# | 4   | 15804002 | Male   | 19  | 76000           | 0         |
#
# ### Checking for null values<a href="#Checking-for-null-values" class="anchor-link">¶</a>
#
# In \[4\]:
#
#     df.isnull().sum()
#
# Out\[4\]:
#
#     User ID            0
#     Gender             0
#     Age                0
#     EstimatedSalary    0
#     Purchased          0
#     dtype: int64
#
# ### Classifying dependant and independent variables<a href="#Classifying-dependant-and-independent-variables" class="anchor-link">¶</a>
#
# In \[5\]:
#
#     dependant_cols = ['Gender','Age','EstimatedSalary']
#     #getting column values
#     X = df[dependant_cols]
#
#     X['Gender'].replace({'Male':1,'Female':0},inplace = True)
#
#     Y = df['Purchased']     #target column
#
#     print('X\n',X,'\n\n\nY\n',Y)
#
#     X
#           Gender  Age  EstimatedSalary
#     0         1   19            19000
#     1         1   35            20000
#     2         0   26            43000
#     3         0   27            57000
#     4         1   19            76000
#     ..      ...  ...              ...
#     395       0   46            41000
#     396       1   51            23000
#     397       0   50            20000
#     398       1   36            33000
#     399       0   49            36000
#
#     [400 rows x 3 columns]
#
#
#     Y
#      0      0
#     1      0
#     2      0
#     3      0
#     4      0
#           ..
#     395    1
#     396    1
#     397    1
#     398    0
#     399    1
#     Name: Purchased, Length: 400, dtype: int64
#
#     /home/pict/.local/lib/python3.6/site-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
#     A value is trying to be set on a copy of a slice from a DataFrame
#
#     See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       method=method,
#
# ### Spliting the dataset<a href="#Spliting-the-dataset" class="anchor-link">¶</a>
#
# In \[6\]:
#
#     from sklearn.model_selection import train_test_split
#
# In \[7\]:
#
#     X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=5)
#
# ### Training the model<a href="#Training-the-model" class="anchor-link">¶</a>
#
# In \[8\]:
#
#     from sklearn.linear_model import LogisticRegression
#
# In \[9\]:
#
#     logistic_regression = LogisticRegression()
#     logistic_regression.fit(X_train, Y_train)
#     y_train_predict = logistic_regression.predict(X_train)
#     y_test_predict = logistic_regression.predict(X_test)
#
# ### Model Evaluation<a href="#Model-Evaluation" class="anchor-link">¶</a>
#
# In \[10\]:
#
#     from sklearn.metrics import mean_squared_error
#     from sklearn.metrics import mean_absolute_error
#     from sklearn.metrics import r2_score
#
# #### Model Evaluation for training<a href="#Model-Evaluation-for-training" class="anchor-link">¶</a>
#
# In \[11\]:
#
#     print("The model performance for training set")
#     print("--------------------------------------")
#     print("RMSE : ", np.sqrt(mean_squared_error(Y_train, y_train_predict)))
#     print("MSE : ", mean_squared_error(Y_train, y_train_predict))
#     print("MAE : ", mean_absolute_error(Y_train, y_train_predict))
#     print("R2 Score : ", r2_score(Y_train, y_train_predict))
#
#     The model performance for training set
#     --------------------------------------
#     RMSE :  0.6020797289396148
#     MSE :  0.3625
#     MAE :  0.3625
#     R2 Score :  -0.5686274509803924
#
# #### Model Evaluation for testing<a href="#Model-Evaluation-for-testing" class="anchor-link">¶</a>
#
# In \[12\]:
#
#     print("The model performance for testing set")
#     print("--------------------------------------")
#     print("RMSE : ", np.sqrt(mean_squared_error(Y_test, y_test_predict)))
#     print("MSE : ", mean_squared_error(Y_test, y_test_predict))
#     print("MAE : ", mean_absolute_error(Y_test, y_test_predict))
#     print("R2 Score : ", r2_score(Y_test, y_test_predict))
#
#     The model performance for testing set
#     --------------------------------------
#     RMSE :  0.5809475019311126
#     MSE :  0.3375
#     MAE :  0.3375
#     R2 Score :  -0.5094339622641506
#
# ### Displaying Confusion Matrix<a href="#Displaying-Confusion-Matrix" class="anchor-link">¶</a>
#
# In \[23\]:
#
#     from sklearn import metrics
#
#     confusion_matrix = metrics.confusion_matrix(Y_test, y_test_predict)
#     confusion_matrix
#
#     ax = sns.heatmap(confusion_matrix, annot=True, cmap='Blues')
#     ax.set_title('Confusion Matrix\n');
#     ax.set_xlabel('\nActual Values')
#     ax.set_ylabel('Predicted Values ');
#     ax.xaxis.set_ticklabels(['Positive','Negative'])
#     ax.yaxis.set_ticklabels(['Positive','Negative'])
#     plt.show()
#
# ![](attachment:vertopal_dbed9caa98d14d52a2654461c725e37a/abcfb1b3c1c8f5595e90c5b050411123020f67d6.png)
#
# ### Printing TP, TN, FP, FN<a href="#Printing-TP,-TN,-FP,-FN" class="anchor-link">¶</a>
#
# In \[22\]:
#
#     true_positive, true_negative, false_negative, false_positive, = confusion_matrix.ravel()
#     print('True Positive :', true_positive)
#     print('True Negative : ', true_negative)
#     print('False Positive : ', false_positive)
#     print('False Negative : ', false_negative)
#
#     True Positive : 53
#     True Negative :  0
#     False Positive :  0
#     False Negative :  27
#
# ### Accuracy<a href="#Accuracy" class="anchor-link">¶</a>
#
# In \[15\]:
#
#     print('Accuracy : ', metrics.accuracy_score(Y_test, y_test_predict))
#     accuracy = (true_positive + true_negative) / (true_positive + true_negative + false_positive + false_negative)
#     print('Accuracy : ', accuracy)
#
#     Accuracy :  0.6625
#     Accuracy :  0.6625
#
# ### Error rate<a href="#Error-rate" class="anchor-link">¶</a>
#
# In \[16\]:
#
#     error_rate = (false_positive + false_negative) / (true_positive + true_negative + false_positive + false_negative)
#     print('Error Rate : ', error_rate)
#
#     Error Rate :  0.3375
#
# ### Precision<a href="#Precision" class="anchor-link">¶</a>
#
# In \[17\]:
#
#     precision = (true_positive) / (true_positive + false_positive)
#     print('Precision : ', precision)
#
#     Precision :  0.6625
#
# ### Recall<a href="#Recall" class="anchor-link">¶</a>
#
# In \[18\]:
#
#     recall = (true_positive) / (true_positive + false_negative)
#     print('Recall : ', recall)
#
#     Recall :  1.0
